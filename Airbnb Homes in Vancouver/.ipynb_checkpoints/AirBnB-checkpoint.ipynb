# %% [markdown]
# ### Data Source
#
# The datasets shows different features for the listings available on Airbnb website on March 8, 2019.
#
# The data is dowloaded from [Inside Airbnb website](http://insideairbnb.com/get-the-data.html) where information is available under a Creative Commons CC0 1.0 Universal (CC0 1.0) "Public Domain Dedication" license.
#
# The datasets are specific to the City of Vancouver and are provided in 5 separate CSV and 1 GeoJSON files:
#
# |File Name | Description
# |:---------|:---------
# |`calendar.csv` | Detailed Calendar Data for listings in Vancouver
# |`listings.csv` | Summary information and metrics for listings in Vancouver
# |`listings-2.csv` | Detailed Listings data for Vancouver
# |`reviews.csv` | Summary Review data and Listing ID
# |`reviews-2.csv` | Detailed Review Data for listings in Vancouver
# |`neighbourhoods.csv` | Neighbourhood list for geo filter (ourced from city or open source GIS files)
# |`neighbourhoods.geojson` | GeoJSON file of neighbourhoods of the city

# %%
# Importing libraries:
import pandas as pd
import numpy as np

# %%
# Importing raw datasets:
df_cal = pd.read_csv('Data/calendar.csv')
df_listings = pd.read_csv('Data/listings.csv')
df_listings_more = pd.read_csv('Data/listings-2.csv')
df_neighb = pd.read_csv('Data/neighbourhoods.csv')
df_reviews = pd.read_csv('Data/reviews.csv')
df_reviews_more = pd.read_csv('Data/reviews-2.csv')

# %% [markdown]
# ### Listings
#
# Let's start by looking at the two listing datasets: `df_listings` and `df_listings_more`

# %%
print('Shape of df_listings:\t\t', df_listings.shape)
print('Shape of df_listings_more:\t', df_listings_more.shape)
# Out:
# Shape of df_listings:		 (4938, 16)
# Shape of df_listings_more:	 (4938, 106)

# %%
df_listings.head(3).T
# Out:
#                                                              0  \
# id                                                       10080
# name                            D1 -  Million Dollar View 2 BR
# host_id                                                  30899
# host_name                                                 Rami
# neighbourhood_group                                        NaN
# neighbourhood                                         Downtown
# latitude                                               49.2877
# longitude                                             -123.121
# room_type                                      Entire home/apt
# price                                                      296
# minimum_nights                                              60
# number_of_reviews                                           16
# last_review                                         2017-02-26
# reviews_per_month                                         0.18
# calculated_host_listings_count                              33
# availability_365                                           191
#
#                                                                   1  \
# id                                                            11400
# name                            Central Lovely Rm in Victorian Home
# host_id                                                       42305
# host_name                                                    Jaynne
# neighbourhood_group                                             NaN
# neighbourhood                                            Riley Park
# latitude                                                    49.2538
# longitude                                                  -123.113
# room_type                                              Private room
# price                                                            60
# minimum_nights                                                  364
# number_of_reviews                                                70
# last_review                                              2016-06-14
# reviews_per_month                                              0.64
# calculated_host_listings_count                                    1
# availability_365                                                365
#
#                                                                 2
# id                                                          13188
# name                            Garden level studio in ideal loc.
# host_id                                                     51466
# host_name                                             Family Guns
# neighbourhood_group                                           NaN
# neighbourhood                                          Riley Park
# latitude                                                  49.2458
# longitude                                                -123.105
# room_type                                         Entire home/apt
# price                                                         120
# minimum_nights                                                  2
# number_of_reviews                                             171
# last_review                                            2019-02-24
# reviews_per_month                                            1.55
# calculated_host_listings_count                                  1
# availability_365                                              214

# %% [markdown]
# We drop the columns that we do not need in the analysis (not required or repeated on other datasets):

# %%
df_listings.drop(['neighbourhood_group', 'last_review', 'reviews_per_month', 'availability_365', 'neighbourhood'], 
                 axis = 1, inplace = True)

# %%
#Checking for NaNs:
df_listings.isna().sum()
# Out:
# id                                0
# name                              1
# host_id                           0
# host_name                         0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# calculated_host_listings_count    0
# dtype: int64

# %% [markdown]
# We'll deal with that one missing value later.

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

df_listings_more.head().T
# Out:
#                                                                                               0  \
# id                                                                                        10080
# listing_url                                                  https://www.airbnb.com/rooms/10080
# scrape_id                                                                        20190308052700
# last_scraped                                                                         2019-03-08
# name                                                             D1 -  Million Dollar View 2 BR
# summary                                       Stunning two bedroom, two bathroom apartment. ...
# space                                         Bed setup: 2 x queen, I can add up to 2 twin s...
# description                                   Stunning two bedroom, two bathroom apartment. ...
# experiences_offered                                                                        none
# neighborhood_overview                                                                       NaN
# notes                                         1. CHECK-IN TIME IS AFTER 3PM PST AND CHECK-OU...
# transit                                                                                     NaN
# access                                           There is no access to the building ammenities.
# interaction                                                                                 NaN
# house_rules                                   1. CHECK-IN TIME IS AFTER 3 PM PST AND CHECK-O...
# thumbnail_url                                                                               NaN
# medium_url                                                                                  NaN
# picture_url                                   https://a0.muscache.com/im/pictures/55778229/c...
# xl_picture_url                                                                              NaN
# host_id                                                                                   30899
# host_url                                                https://www.airbnb.com/users/show/30899
# host_name                                                                                  Rami
# host_since                                                                           2009-08-10
# host_location                                               Vancouver, British Columbia, Canada
# host_about                                                         I will be happy to host you.
# host_response_time                                                           within a few hours
# host_response_rate                                                                         100%
# host_acceptance_rate                                                                        NaN
# host_is_superhost                                                                             f
# host_thumbnail_url                            https://a0.muscache.com/im/pictures/user/55302...
# host_picture_url                              https://a0.muscache.com/im/pictures/user/55302...
# host_neighbourhood                                                                 Coal Harbour
# host_listings_count                                                                          33
# host_total_listings_count                                                                    33
# host_verifications                            ['email', 'phone', 'reviews', 'jumio', 'govern...
# host_has_profile_pic                                                                          t
# host_identity_verified                                                                        t
# street                                                                    Vancouver, BC, Canada
# neighbourhood                                                                      Coal Harbour
# neighbourhood_cleansed                                                                 Downtown
# neighbourhood_group_cleansed                                                                NaN
# city                                                                                  Vancouver
# state                                                                                        BC
# zipcode                                                                                 V6E 2P4
# market                                                                                Vancouver
# smart_location                                                                Vancouver, Canada
# country_code                                                                                 CA
# country                                                                                  Canada
# latitude                                                                                49.2877
# longitude                                                                              -123.121
# is_location_exact                                                                             t
# property_type                                                                       Condominium
# room_type                                                                       Entire home/apt
# accommodates                                                                                  6
# bathrooms                                                                                     2
# bedrooms                                                                                      2
# beds                                                                                          4
# bed_type                                                                               Real Bed
# amenities                                     {TV,"Cable TV",Internet,Wifi,"Air conditioning...
# square_feet                                                                                1200
# price                                                                                   $296.00
# weekly_price                                                                                NaN
# monthly_price                                                                         $4,750.00
# security_deposit                                                                          $0.00
# cleaning_fee                                                                            $195.00
# guests_included                                                                               1
# extra_people                                                                              $0.00
# minimum_nights                                                                               60
# maximum_nights                                                                             1124
# minimum_minimum_nights                                                                       60
# maximum_minimum_nights                                                                       60
# minimum_maximum_nights                                                                     1124
# maximum_maximum_nights                                                                     1124
# minimum_nights_avg_ntm                                                                       60
# maximum_nights_avg_ntm                                                                     1124
# calendar_updated                                                                          today
# has_availability                                                                              t
# availability_30                                                                               0
# availability_60                                                                               0
# availability_90                                                                               0
# availability_365                                                                            191
# calendar_last_scraped                                                                2019-03-08
# number_of_reviews                                                                            16
# number_of_reviews_ltm                                                                         0
# first_review                                                                         2011-11-15
# last_review                                                                          2017-02-26
# review_scores_rating                                                                         93
# review_scores_accuracy                                                                        9
# review_scores_cleanliness                                                                     9
# review_scores_checkin                                                                        10
# review_scores_communication                                                                   9
# review_scores_location                                                                       10
# review_scores_value                                                                           9
# requires_license                                                                              t
# license                                                                               18-476608
# jurisdiction_names                            {"British Columbia"," Canada"," Vancouver"," B...
# instant_bookable                                                                              f
# is_business_travel_ready                                                                      f
# cancellation_policy                                                 strict_14_with_grace_period
# require_guest_profile_picture                                                                 f
# require_guest_phone_verification                                                              f
# calculated_host_listings_count                                                               33
# calculated_host_listings_count_entire_homes                                                  33
# calculated_host_listings_count_private_rooms                                                  0
# calculated_host_listings_count_shared_rooms                                                   0
# reviews_per_month                                                                          0.18
#
#                                                                                               1  \
# id                                                                                        11400
# listing_url                                                  https://www.airbnb.com/rooms/11400
# scrape_id                                                                        20190308052700
# last_scraped                                                                         2019-03-08
# name                                                        Central Lovely Rm in Victorian Home
# summary                                       Well-appointed room with a view of the garden ...
# space                                         Centrally-located lovely, quiet home on tree-l...
# description                                   Well-appointed room with a view of the garden ...
# experiences_offered                                                                        none
# neighborhood_overview                         Very quiet residential area, yet only 1-1/2 bl...
# notes                                                                                       NaN
# transit                                       Bus stop 1-1/2 blocks away. 15 minutes to down...
# access                                        Access to my home and garden. Shared bathroom....
# interaction                                   I live here so will interact with the guest wh...
# house_rules                                   -No smoking indoors.  -Recycling, composting  ...
# thumbnail_url                                                                               NaN
# medium_url                                                                                  NaN
# picture_url                                   https://a0.muscache.com/im/pictures/74189163/a...
# xl_picture_url                                                                              NaN
# host_id                                                                                   42305
# host_url                                                https://www.airbnb.com/users/show/42305
# host_name                                                                                Jaynne
# host_since                                                                           2009-09-30
# host_location                                               Vancouver, British Columbia, Canada
# host_about                                    I am a self-employed graphic designer, AutoCAD...
# host_response_time                                                                          NaN
# host_response_rate                                                                          NaN
# host_acceptance_rate                                                                        NaN
# host_is_superhost                                                                             f
# host_thumbnail_url                            https://a0.muscache.com/im/users/42305/profile...
# host_picture_url                              https://a0.muscache.com/im/users/42305/profile...
# host_neighbourhood                                                                   Riley Park
# host_listings_count                                                                           1
# host_total_listings_count                                                                     1
# host_verifications                            ['email', 'phone', 'reviews', 'jumio', 'govern...
# host_has_profile_pic                                                                          t
# host_identity_verified                                                                        t
# street                                                                    Vancouver, BC, Canada
# neighbourhood                                                                        Riley Park
# neighbourhood_cleansed                                                               Riley Park
# neighbourhood_group_cleansed                                                                NaN
# city                                                                                  Vancouver
# state                                                                                        BC
# zipcode                                                                                     V5Y
# market                                                                                Vancouver
# smart_location                                                                Vancouver, Canada
# country_code                                                                                 CA
# country                                                                                  Canada
# latitude                                                                                49.2538
# longitude                                                                              -123.113
# is_location_exact                                                                             t
# property_type                                                                             House
# room_type                                                                          Private room
# accommodates                                                                                  1
# bathrooms                                                                                     1
# bedrooms                                                                                      1
# beds                                                                                          1
# bed_type                                                                               Real Bed
# amenities                                     {TV,"Cable TV",Internet,Wifi,"Free parking on ...
# square_feet                                                                                   0
# price                                                                                    $60.00
# weekly_price                                                                            $385.00
# monthly_price                                                                         $1,400.00
# security_deposit                                                                            NaN
# cleaning_fee                                                                                NaN
# guests_included                                                                               1
# extra_people                                                                              $0.00
# minimum_nights                                                                              364
# maximum_nights                                                                              364
# minimum_minimum_nights                                                                      364
# maximum_minimum_nights                                                                      364
# minimum_maximum_nights                                                                      364
# maximum_maximum_nights                                                                      364
# minimum_nights_avg_ntm                                                                      364
# maximum_nights_avg_ntm                                                                      364
# calendar_updated                                                                  11 months ago
# has_availability                                                                              t
# availability_30                                                                              30
# availability_60                                                                              60
# availability_90                                                                              90
# availability_365                                                                            365
# calendar_last_scraped                                                                2019-03-08
# number_of_reviews                                                                            70
# number_of_reviews_ltm                                                                         0
# first_review                                                                         2010-02-18
# last_review                                                                          2016-06-14
# review_scores_rating                                                                         92
# review_scores_accuracy                                                                        9
# review_scores_cleanliness                                                                    10
# review_scores_checkin                                                                        10
# review_scores_communication                                                                  10
# review_scores_location                                                                       10
# review_scores_value                                                                           9
# requires_license                                                                              t
# license                                                                                     NaN
# jurisdiction_names                            {"British Columbia"," Canada"," Vancouver"," B...
# instant_bookable                                                                              f
# is_business_travel_ready                                                                      f
# cancellation_policy                                                 strict_14_with_grace_period
# require_guest_profile_picture                                                                 t
# require_guest_phone_verification                                                              t
# calculated_host_listings_count                                                                1
# calculated_host_listings_count_entire_homes                                                   0
# calculated_host_listings_count_private_rooms                                                  1
# calculated_host_listings_count_shared_rooms                                                   0
# reviews_per_month                                                                          0.64
#
#                                                                                               2  \
# id                                                                                        13188
# listing_url                                                  https://www.airbnb.com/rooms/13188
# scrape_id                                                                        20190308052700
# last_scraped                                                                         2019-03-08
# name                                                          Garden level studio in ideal loc.
# summary                                       Garden level studio suite with garden patio - ...
# space                                         Explore Vancouver in a highly sought after, tr...
# description                                   Garden level studio suite with garden patio - ...
# experiences_offered                                                                        none
# neighborhood_overview                                                                       NaN
# notes                                                                                       NaN
# transit                                                                                     NaN
# access                                                                                      NaN
# interaction                                   We live in the house in which the suite is loc...
# house_rules                                    Limited noise after 11:00pm. Strictly NO SMOKING
# thumbnail_url                                                                               NaN
# medium_url                                                                                  NaN
# picture_url                                   https://a0.muscache.com/im/pictures/8408188/e1...
# xl_picture_url                                                                              NaN
# host_id                                                                                   51466
# host_url                                                https://www.airbnb.com/users/show/51466
# host_name                                                                           Family Guns
# host_since                                                                           2009-11-04
# host_location                                               Vancouver, British Columbia, Canada
# host_about                                    We are a family of four who love to travel in ...
# host_response_time                                                               within an hour
# host_response_rate                                                                         100%
# host_acceptance_rate                                                                        NaN
# host_is_superhost                                                                             t
# host_thumbnail_url                            https://a0.muscache.com/im/users/51466/profile...
# host_picture_url                              https://a0.muscache.com/im/users/51466/profile...
# host_neighbourhood                                                                   Riley Park
# host_listings_count                                                                           1
# host_total_listings_count                                                                     1
# host_verifications                            ['email', 'phone', 'facebook', 'reviews', 'jum...
# host_has_profile_pic                                                                          t
# host_identity_verified                                                                        t
# street                                                                    Vancouver, BC, Canada
# neighbourhood                                                                        Riley Park
# neighbourhood_cleansed                                                               Riley Park
# neighbourhood_group_cleansed                                                                NaN
# city                                                                                  Vancouver
# state                                                                                        BC
# zipcode                                                                                     V5Y
# market                                                                                Vancouver
# smart_location                                                                Vancouver, Canada
# country_code                                                                                 CA
# country                                                                                  Canada
# latitude                                                                                49.2458
# longitude                                                                              -123.105
# is_location_exact                                                                             t
# property_type                                                                         Apartment
# room_type                                                                       Entire home/apt
# accommodates                                                                                  4
# bathrooms                                                                                     1
# bedrooms                                                                                      0
# beds                                                                                          2
# bed_type                                                                               Real Bed
# amenities                                     {TV,"Cable TV",Internet,Wifi,Kitchen,"Free par...
# square_feet                                                                                 NaN
# price                                                                                   $120.00
# weekly_price                                                                            $750.00
# monthly_price                                                                         $2,500.00
# security_deposit                                                                          $0.00
# cleaning_fee                                                                             $40.00
# guests_included                                                                               1
# extra_people                                                                              $0.00
# minimum_nights                                                                                2
# maximum_nights                                                                             1125
# minimum_minimum_nights                                                                        2
# maximum_minimum_nights                                                                        2
# minimum_maximum_nights                                                                     1125
# maximum_maximum_nights                                                                     1125
# minimum_nights_avg_ntm                                                                        2
# maximum_nights_avg_ntm                                                                     1125
# calendar_updated                                                                    4 weeks ago
# has_availability                                                                              t
# availability_30                                                                               7
# availability_60                                                                              12
# availability_90                                                                              20
# availability_365                                                                            214
# calendar_last_scraped                                                                2019-03-08
# number_of_reviews                                                                           171
# number_of_reviews_ltm                                                                        30
# first_review                                                                         2010-02-21
# last_review                                                                          2019-02-24
# review_scores_rating                                                                         96
# review_scores_accuracy                                                                       10
# review_scores_cleanliness                                                                    10
# review_scores_checkin                                                                        10
# review_scores_communication                                                                  10
# review_scores_location                                                                       10
# review_scores_value                                                                          10
# requires_license                                                                              t
# license                                                                               19-162013
# jurisdiction_names                            {"British Columbia"," Canada"," Vancouver"," B...
# instant_bookable                                                                              t
# is_business_travel_ready                                                                      f
# cancellation_policy                                                                    moderate
# require_guest_profile_picture                                                                 f
# require_guest_phone_verification                                                              f
# calculated_host_listings_count                                                                1
# calculated_host_listings_count_entire_homes                                                   1
# calculated_host_listings_count_private_rooms                                                  0
# calculated_host_listings_count_shared_rooms                                                   0
# reviews_per_month                                                                          1.55
#
#                                                                                               3  \
# id                                                                                        13357
# listing_url                                                  https://www.airbnb.com/rooms/13357
# scrape_id                                                                        20190308052700
# last_scraped                                                                         2019-03-08
# name                                          ! Wow! 2bed 2bath 1bed den Harbour View Apartm...
# summary                                       Very spacious and comfortable with very well k...
# space                                         Mountains and harbour view 2 bedroom,2 bath,1 ...
# description                                   Very spacious and comfortable with very well k...
# experiences_offered                                                                        none
# neighborhood_overview                         Amanzing bibrant professional neighbourhood. C...
# notes                                         Some strata bylaws that need to follow and res...
# transit                                                                                     NaN
# access                                        The entire apartment . Except no included the ...
# interaction                                   I'm personally. Do that wellcome check in and ...
# house_rules                                   No parties,no smoking,no pets. Damages deposit...
# thumbnail_url                                                                               NaN
# medium_url                                                                                  NaN
# picture_url                                   https://a0.muscache.com/im/pictures/195991/737...
# xl_picture_url                                                                              NaN
# host_id                                                                                   52118
# host_url                                                https://www.airbnb.com/users/show/52118
# host_name                                                                               Liliana
# host_since                                                                           2009-11-07
# host_location                                               Vancouver, British Columbia, Canada
# host_about                                    We are very well travel couple that we like to...
# host_response_time                                                               within an hour
# host_response_rate                                                                         100%
# host_acceptance_rate                                                                        NaN
# host_is_superhost                                                                             f
# host_thumbnail_url                            https://a0.muscache.com/im/pictures/user/047eb...
# host_picture_url                              https://a0.muscache.com/im/pictures/user/047eb...
# host_neighbourhood                                                                    Chinatown
# host_listings_count                                                                           3
# host_total_listings_count                                                                     3
# host_verifications                            ['email', 'phone', 'reviews', 'jumio', 'offlin...
# host_has_profile_pic                                                                          t
# host_identity_verified                                                                        t
# street                                                                    Vancouver, BC, Canada
# neighbourhood                                                                Downtown Vancouver
# neighbourhood_cleansed                                                        Downtown Eastside
# neighbourhood_group_cleansed                                                                NaN
# city                                                                                  Vancouver
# state                                                                                        BC
# zipcode                                                                                     V6B
# market                                                                                Vancouver
# smart_location                                                                Vancouver, Canada
# country_code                                                                                 CA
# country                                                                                  Canada
# latitude                                                                                49.2796
# longitude                                                                              -123.105
# is_location_exact                                                                             t
# property_type                                                                         Apartment
# room_type                                                                       Entire home/apt
# accommodates                                                                                  4
# bathrooms                                                                                     2
# bedrooms                                                                                      2
# beds                                                                                          2
# bed_type                                                                               Real Bed
# amenities                                     {TV,"Cable TV",Internet,Wifi,"Wheelchair acces...
# square_feet                                                                                 NaN
# price                                                                                   $155.00
# weekly_price                                                                          $1,000.00
# monthly_price                                                                         $2,957.00
# security_deposit                                                                        $806.00
# cleaning_fee                                                                            $202.00
# guests_included                                                                               2
# extra_people                                                                             $34.00
# minimum_nights                                                                               30
# maximum_nights                                                                               30
# minimum_minimum_nights                                                                       30
# maximum_minimum_nights                                                                       30
# minimum_maximum_nights                                                                       30
# maximum_maximum_nights                                                                       30
# minimum_nights_avg_ntm                                                                       30
# maximum_nights_avg_ntm                                                                       30
# calendar_updated                                                                          today
# has_availability                                                                              t
# availability_30                                                                              30
# availability_60                                                                              60
# availability_90                                                                              90
# availability_365                                                                            304
# calendar_last_scraped                                                                2019-03-08
# number_of_reviews                                                                            56
# number_of_reviews_ltm                                                                         3
# first_review                                                                         2010-02-26
# last_review                                                                          2018-08-31
# review_scores_rating                                                                         84
# review_scores_accuracy                                                                        8
# review_scores_cleanliness                                                                     9
# review_scores_checkin                                                                         8
# review_scores_communication                                                                   8
# review_scores_location                                                                        8
# review_scores_value                                                                           8
# requires_license                                                                              t
# license                                                                                     NaN
# jurisdiction_names                            {"British Columbia"," Canada"," Vancouver"," B...
# instant_bookable                                                                              f
# is_business_travel_ready                                                                      f
# cancellation_policy                                                 strict_14_with_grace_period
# require_guest_profile_picture                                                                 t
# require_guest_phone_verification                                                              t
# calculated_host_listings_count                                                                2
# calculated_host_listings_count_entire_homes                                                   2
# calculated_host_listings_count_private_rooms                                                  0
# calculated_host_listings_count_shared_rooms                                                   0
# reviews_per_month                                                                          0.51
#
#                                                                                               4
# id                                                                                        13358
# listing_url                                                  https://www.airbnb.com/rooms/13358
# scrape_id                                                                        20190308052700
# last_scraped                                                                         2019-03-08
# name                                          Urban Boutique Suite heart of Downtown Vancouver!
# summary                                                                                     NaN
# space                                         Welcome to the Electra Building on Nelson stre...
# description                                   Welcome to the Electra Building on Nelson stre...
# experiences_offered                                                                        none
# neighborhood_overview                                                                       NaN
# notes                                                                                       NaN
# transit                                                                                     NaN
# access                                                                                      NaN
# interaction                                                                                 NaN
# house_rules                                   NO PETS AND NO SMOKING PLEASE  **One time $60 ...
# thumbnail_url                                                                               NaN
# medium_url                                                                                  NaN
# picture_url                                   https://a0.muscache.com/im/pictures/630418/fb0...
# xl_picture_url                                                                              NaN
# host_id                                                                                   52116
# host_url                                                https://www.airbnb.com/users/show/52116
# host_name                                                                                  Lynn
# host_since                                                                           2009-11-07
# host_location                                               Vancouver, British Columbia, Canada
# host_about                                    I am from Vancouver and in my free time enjoy ...
# host_response_time                                                               within an hour
# host_response_rate                                                                         100%
# host_acceptance_rate                                                                        NaN
# host_is_superhost                                                                             f
# host_thumbnail_url                            https://a0.muscache.com/im/pictures/88e0c5ef-2...
# host_picture_url                              https://a0.muscache.com/im/pictures/88e0c5ef-2...
# host_neighbourhood                                                           Downtown Vancouver
# host_listings_count                                                                           1
# host_total_listings_count                                                                     1
# host_verifications                            ['email', 'phone', 'facebook', 'reviews', 'jum...
# host_has_profile_pic                                                                          t
# host_identity_verified                                                                        f
# street                                                                    Vancouver, BC, Canada
# neighbourhood                                                                Downtown Vancouver
# neighbourhood_cleansed                                                                 West End
# neighbourhood_group_cleansed                                                                NaN
# city                                                                                  Vancouver
# state                                                                                        BC
# zipcode                                                                                 V6Z 2S1
# market                                                                                Vancouver
# smart_location                                                                Vancouver, Canada
# country_code                                                                                 CA
# country                                                                                  Canada
# latitude                                                                                49.2821
# longitude                                                                              -123.125
# is_location_exact                                                                             t
# property_type                                                                       Condominium
# room_type                                                                       Entire home/apt
# accommodates                                                                                  2
# bathrooms                                                                                     1
# bedrooms                                                                                      1
# beds                                                                                          1
# bed_type                                                                               Real Bed
# amenities                                     {TV,"Cable TV",Internet,Wifi,"Air conditioning...
# square_feet                                                                                   0
# price                                                                                   $120.00
# weekly_price                                                                            $750.00
# monthly_price                                                                               NaN
# security_deposit                                                                        $300.00
# cleaning_fee                                                                             $65.00
# guests_included                                                                               1
# extra_people                                                                              $0.00
# minimum_nights                                                                                1
# maximum_nights                                                                               60
# minimum_minimum_nights                                                                        1
# maximum_minimum_nights                                                                        1
# minimum_maximum_nights                                                                       60
# maximum_maximum_nights                                                                       60
# minimum_nights_avg_ntm                                                                        1
# maximum_nights_avg_ntm                                                                       60
# calendar_updated                                                                     a week ago
# has_availability                                                                              t
# availability_30                                                                               2
# availability_60                                                                              12
# availability_90                                                                              21
# availability_365                                                                             23
# calendar_last_scraped                                                                2019-03-08
# number_of_reviews                                                                           393
# number_of_reviews_ltm                                                                        80
# first_review                                                                         2010-06-22
# last_review                                                                          2019-02-21
# review_scores_rating                                                                         94
# review_scores_accuracy                                                                       10
# review_scores_cleanliness                                                                    10
# review_scores_checkin                                                                        10
# review_scores_communication                                                                  10
# review_scores_location                                                                       10
# review_scores_value                                                                           9
# requires_license                                                                              t
# license                                                                               18-611603
# jurisdiction_names                            {"British Columbia"," Canada"," Vancouver"," B...
# instant_bookable                                                                              f
# is_business_travel_ready                                                                      f
# cancellation_policy                                                 strict_14_with_grace_period
# require_guest_profile_picture                                                                 f
# require_guest_phone_verification                                                              t
# calculated_host_listings_count                                                                1
# calculated_host_listings_count_entire_homes                                                   1
# calculated_host_listings_count_private_rooms                                                  0
# calculated_host_listings_count_shared_rooms                                                   0
# reviews_per_month                                                                          3.71

# %%
columns_to_keep = ['id', 'summary', 'space', 'description', 'host_listings_count', 'host_total_listings_count',
                  'neighbourhood_cleansed', 'is_location_exact', 'property_type', 'accommodates', 'bedrooms',
                  'bathrooms', 'beds', 'amenities', 'availability_30', 'availability_60', 'availability_90',
                  'availability_365']

df_listings_more = df_listings_more.loc[:,columns_to_keep]

# %%
df_listings_more.dtypes
# Out:
# id                             int64
# summary                       object
# space                         object
# description                   object
# host_listings_count            int64
# host_total_listings_count      int64
# neighbourhood_cleansed        object
# is_location_exact             object
# property_type                 object
# accommodates                   int64
# bedrooms                     float64
# bathrooms                    float64
# beds                         float64
# amenities                     object
# availability_30                int64
# availability_60                int64
# availability_90                int64
# availability_365               int64
# dtype: object

# %%
df_listings_more.isna().sum()
# Out:
# id                              0
# summary                       167
# space                        1057
# description                    81
# host_listings_count             0
# host_total_listings_count       0
# neighbourhood_cleansed          0
# is_location_exact               0
# property_type                   0
# accommodates                    0
# bedrooms                        3
# bathrooms                       0
# beds                            5
# amenities                       0
# availability_30                 0
# availability_60                 0
# availability_90                 0
# availability_365                0
# dtype: int64

# %%
df_listings_more['summary'] = df_listings_more['summary'].fillna('')
df_listings_more['space'] = df_listings_more['space'].fillna('')
df_listings_more['description'] = df_listings_more['description'].fillna('')

# %%
df_listings_more.isna().sum()
# Out:
# id                           0
# summary                      0
# space                        0
# description                  0
# host_listings_count          0
# host_total_listings_count    0
# neighbourhood_cleansed       0
# is_location_exact            0
# property_type                0
# accommodates                 0
# bedrooms                     3
# bathrooms                    0
# beds                         5
# amenities                    0
# availability_30              0
# availability_60              0
# availability_90              0
# availability_365             0
# dtype: int64

# %%
print('Shape of df_listings:\t\t', df_listings.shape)
print('Shape of df_listings_more:\t', df_listings_more.shape)
# Out:
# Shape of df_listings:		 (4938, 11)
# Shape of df_listings_more:	 (4938, 18)

# %%
df_listings.dtypes
# Out:
# id                                  int64
# name                               object
# host_id                             int64
# host_name                          object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# calculated_host_listings_count      int64
# dtype: object

# %%
df_listings_more.dtypes
# Out:
# id                             int64
# summary                       object
# space                         object
# description                   object
# host_listings_count            int64
# host_total_listings_count      int64
# neighbourhood_cleansed        object
# is_location_exact             object
# property_type                 object
# accommodates                   int64
# bedrooms                     float64
# bathrooms                    float64
# beds                         float64
# amenities                     object
# availability_30                int64
# availability_60                int64
# availability_90                int64
# availability_365               int64
# dtype: object

# %%
df_listings_clean = df_listings.merge(df_listings_more, on = 'id')

# %%
df_listings_clean.isna().sum()
# Out:
# id                                0
# name                              1
# host_id                           0
# host_name                         0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# calculated_host_listings_count    0
# summary                           0
# space                             0
# description                       0
# host_listings_count               0
# host_total_listings_count         0
# neighbourhood_cleansed            0
# is_location_exact                 0
# property_type                     0
# accommodates                      0
# bedrooms                          3
# bathrooms                         0
# beds                              5
# amenities                         0
# availability_30                   0
# availability_60                   0
# availability_90                   0
# availability_365                  0
# dtype: int64

# %%
df_listings_clean.dropna(axis = 0, inplace = True)

# %%
df_listings_clean.isna().sum().any()
# Out:
# False

# %%
df_listings_clean.dtypes
# Out:
# id                                  int64
# name                               object
# host_id                             int64
# host_name                          object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# calculated_host_listings_count      int64
# summary                            object
# space                              object
# description                        object
# host_listings_count                 int64
# host_total_listings_count           int64
# neighbourhood_cleansed             object
# is_location_exact                  object
# property_type                      object
# accommodates                        int64
# bedrooms                          float64
# bathrooms                         float64
# beds                              float64
# amenities                          object
# availability_30                     int64
# availability_60                     int64
# availability_90                     int64
# availability_365                    int64
# dtype: object

# %%
df_listings_clean['bedrooms'] = df_listings_clean['bedrooms'].astype('int64')
df_listings_clean['bathrooms'] = df_listings_clean['bathrooms'].astype('int64')
df_listings_clean['beds'] = df_listings_clean['beds'].astype('int64')

# %%
df_listings_clean.to_csv('clean_data.csv')

# %%
df_neighbourhood = pd.DataFrame(index = df_listings_clean['neighbourhood_cleansed'].unique())

# %%
df_neighbourhood['Avg_price'] = df_listings_clean.groupby(by = 'neighbourhood_cleansed')['price']\
                                            .mean().round()

df_neighbourhood['Listing_count'] = df_listings_clean.groupby(by = 'neighbourhood_cleansed')['id']\
                                            .count()

df_neighbourhood['Avg_30_availability'] = df_listings_clean.groupby(by = 'neighbourhood_cleansed')['availability_30']\
                                            .mean()\
                                                .round()\
                                                    .astype(int)

df_neighbourhood['Avg_60_availability'] = df_listings_clean.groupby(by = 'neighbourhood_cleansed')['availability_60']\
                                            .mean()\
                                                .round()\
                                                    .astype(int)

df_neighbourhood['Avg_90_availability'] = df_listings_clean.groupby(by = 'neighbourhood_cleansed')['availability_90']\
                                            .mean()\
                                                .round()\
                                                    .astype(int)

df_neighbourhood['Avg_365_availability'] = df_listings_clean.groupby(by = 'neighbourhood_cleansed')['availability_365']\
                                            .mean()\
                                                .round()\
                                                    .astype(int)

# %%
df_neighbourhood
# Out:
#                           Avg_price  Listing_count  Avg_30_availability  \
# Downtown                      196.0           1064                   11
# Riley Park                    145.0            275                   10
# Downtown Eastside             176.0            271                   12
# West End                      168.0            362                   10
# Kensington-Cedar Cottage      134.0            319                   10
# Hastings-Sunrise              120.0            247                   12
# Renfrew-Collingwood           102.0            200                   12
# Mount Pleasant                150.0            294                   10
# Grandview-Woodland            135.0            247                    8
# Fairview                      144.0            151                    7
# Kitsilano                     190.0            424                   10
# Kerrisdale                    173.0             69                   15
# Arbutus Ridge                 198.0             84                   13
# Sunset                        172.0            106                   13
# Dunbar Southlands             190.0            138                   13
# Marpole                       129.0            166                   17
# Killarney                      91.0             67                   15
# Shaughnessy                   216.0             87                   12
# South Cambie                  185.0             59                   10
# Strathcona                    128.0             22                    8
# West Point Grey               216.0             88                   13
# Oakridge                      141.0             88                   15
# Victoria-Fraserview            90.0            101                   19
#
#                           Avg_60_availability  Avg_90_availability  \
# Downtown                                   25                   41
# Riley Park                                 21                   32
# Downtown Eastside                          25                   38
# West End                                   22                   36
# Kensington-Cedar Cottage                   22                   35
# Hastings-Sunrise                           26                   42
# Renfrew-Collingwood                        27                   43
# Mount Pleasant                             22                   35
# Grandview-Woodland                         17                   28
# Fairview                                   18                   31
# Kitsilano                                  22                   34
# Kerrisdale                                 31                   47
# Arbutus Ridge                              29                   47
# Sunset                                     30                   48
# Dunbar Southlands                          30                   48
# Marpole                                    38                   60
# Killarney                                  34                   53
# Shaughnessy                                26                   39
# South Cambie                               22                   35
# Strathcona                                 20                   32
# West Point Grey                            27                   40
# Oakridge                                   34                   52
# Victoria-Fraserview                        41                   65
#
#                           Avg_365_availability
# Downtown                                   147
# Riley Park                                 117
# Downtown Eastside                          129
# West End                                   117
# Kensington-Cedar Cottage                   136
# Hastings-Sunrise                           138
# Renfrew-Collingwood                        153
# Mount Pleasant                             126
# Grandview-Woodland                         116
# Fairview                                   132
# Kitsilano                                  133
# Kerrisdale                                 145
# Arbutus Ridge                              156
# Sunset                                     142
# Dunbar Southlands                          170
# Marpole                                    167
# Killarney                                  140
# Shaughnessy                                107
# South Cambie                               125
# Strathcona                                 129
# West Point Grey                            133
# Oakridge                                   136
# Victoria-Fraserview                        228

# %%
# Returning the top 50 words:

from operator import itemgetter

def top_word_counter(df, filter_col, filter_match, lookup_col):

    words = list(entry.lower().strip() for entry in df[df[filter_col] == filter_match][lookup_col].astype(str))
    wordcount = {}

    stopwords = ["i", "me", "my", "myself", "we", "our", "ours", "ourselves", "you", "your", "yours", 
                 "yourself", "yourselves", "he", "him", "his", "himself", "she", "her", "hers", "herself", 
                 "it", "its", "itself", "they", "them", "their", "theirs", "themselves", "what", "which", 
                 "who", "whom", "this", "that", "these", "those", "am", "is", "are", "was", "were", "be", 
                 "been", "being", "have", "has", "had", "having", "do", "does", "did", "doing", "a", "an", 
                 "the", "and", "but", "if", "or", "because", "as", "until", "while", "of", "at", "by", "for", 
                 "with", "about", "against", "between", "into", "through", "during", "before", "after", "above", 
                 "below", "to", "from", "up", "down", "in", "out", "on", "off", "over", "under", "again", "further", 
                 "then", "once", "here", "there", "when", "where", "why", "how", "all", "any", "both", "each", 
                 "few", "more", "most", "other", "some", "such", "no", "nor", "not", "only", "own", "same", "so", 
                 "than", "too", "very", "s", "t", "can", "will", "just", "don", "should", "now", ""]

    symbols_to_replace = [".", ",", ":", ";", "\"", "/", "!", "?", "â€œ", "â€˜", "*", ")", "(", "|", 
                          ">", "<", "{", "}", "&", "^", "~", "+"]
    
    seperator = ' '
    text = seperator.join(words)

    for word in text.split():
        for symbol in symbols_to_replace:
            word = word.replace(symbol,"")

        if word not in stopwords:
            if word not in wordcount:
                wordcount[word] = 1
            else:
                wordcount[word] += 1

    top_words = sorted(wordcount.items(), key=itemgetter(1), reverse = True)[0:50]
    
    return [(filter_match, i[0], i[1]) for i in top_words]

# %%
# Finding the top 50 words in names column for each neighbouthood:
name_words = []

for neighb in df_listings_clean['neighbourhood_cleansed'].unique():
    name_words += top_word_counter(df_listings_clean, 'neighbourhood_cleansed', neighb, 'summary')
    print(neighb, 'done!')

name_words = pd.DataFrame(name_words)
name_words.columns = ['neighbourhood_cleansed', 'Word', 'Word_Count']

# Save to csv:
name_words.to_csv('name_words.csv')
# Out:
# Downtown done!
# Riley Park done!
# Downtown Eastside done!
# West End done!
# Kensington-Cedar Cottage done!
# Hastings-Sunrise done!
# Renfrew-Collingwood done!
# Mount Pleasant done!
# Grandview-Woodland done!
# Fairview done!
# Kitsilano done!
# Kerrisdale done!
# Arbutus Ridge done!
# Sunset done!
# Dunbar Southlands done!
# Marpole done!
# Killarney done!
# Shaughnessy done!
# South Cambie done!
# Strathcona done!
# West Point Grey done!
# Oakridge done!
# Victoria-Fraserview done!

# %%
# Finding the top 50 words in summaries for each neighbouthood:
summary_words = []

for neighb in df_listings_clean['neighbourhood_cleansed'].unique():
    summary_words += top_word_counter(df_listings_clean, 'neighbourhood_cleansed', neighb, 'summary')
    print(neighb, 'done!')

summary_words = pd.DataFrame(summary_words)
summary_words.columns = ['neighbourhood_cleansed', 'Word', 'Word_Count']

# Save to csv:
summary_words.to_csv('summary_words.csv')
# Out:
# Downtown done!
# Riley Park done!
# Downtown Eastside done!
# West End done!
# Kensington-Cedar Cottage done!
# Hastings-Sunrise done!
# Renfrew-Collingwood done!
# Mount Pleasant done!
# Grandview-Woodland done!
# Fairview done!
# Kitsilano done!
# Kerrisdale done!
# Arbutus Ridge done!
# Sunset done!
# Dunbar Southlands done!
# Marpole done!
# Killarney done!
# Shaughnessy done!
# South Cambie done!
# Strathcona done!
# West Point Grey done!
# Oakridge done!
# Victoria-Fraserview done!

# %%
# Cleaning the reviews dataframe before checking for most used words:
reviews_clean = df_reviews_more.drop(['id', 'date', 'reviewer_id', 'reviewer_name'] , axis = 1)\
    .rename(columns = {'listing_id': 'id', 'comments': 'review'})\
        .merge(df_listings_more.loc[:, ['id', 'neighbourhood_cleansed']], on = 'id')

# Finding the top 50 words in reviews for each neighbouthood:
review_words = []

for neighb in reviews_clean['neighbourhood_cleansed'].unique():
    review_words += top_word_counter(reviews_clean, 'neighbourhood_cleansed', neighb, 'review')
    print(neighb, 'done!')

review_words = pd.DataFrame(review_words)
review_words.columns = ['neighbourhood_cleansed', 'Word', 'Word_Count']

# Save to csv:
review_words.to_csv('review_words.csv')
# Out:
# Downtown done!
# Riley Park done!
# Downtown Eastside done!
# West End done!
# Kensington-Cedar Cottage done!
# Hastings-Sunrise done!
# Renfrew-Collingwood done!
# Mount Pleasant done!
# Grandview-Woodland done!
# Fairview done!
# Kitsilano done!
# Kerrisdale done!
# Arbutus Ridge done!
# Sunset done!
# Dunbar Southlands done!
# Marpole done!
# Killarney done!
# Shaughnessy done!
# South Cambie done!
# Strathcona done!
# West Point Grey done!
# Oakridge done!
# Victoria-Fraserview done!
